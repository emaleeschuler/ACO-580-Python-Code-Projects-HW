# %% [markdown]
# dale-yxah-yvug-kuqi Emalee Schuler

# %% [markdown]
# Question 1
#
# Observe this sequence of statements and update the Output column with what the program will print as each statement executes.

# %%
print("Hi")
print("there")
print(39 + 3)
print("39+3")
print("x =", 7 + 2)
# Out:
# Hi
# there
# 42
# 39+3
# x = 9

# %% [markdown]
# ![Screenshot%202024-01-11%20at%201.12.24%20PM.png](attachment:Screenshot%202024-01-11%20at%201.12.24%20PM.png)

# %% [markdown]
# Question 2
#
# For each of the code fragments below, correct the error, or type OK if there is no error.

# %% [markdown]
# ![Screenshot%202024-01-11%20at%201.12.32%20PM.png](attachment:Screenshot%202024-01-11%20at%201.12.32%20PM.png)

# %% [markdown]
# Question 3
#
# For each of the following, indicate whether the given action would result in a compile-time or a run-time error.

# %% [markdown]
# ![Screenshot%202024-01-11%20at%201.12.40%20PM.png](attachment:Screenshot%202024-01-11%20at%201.12.40%20PM.png)

# %% [markdown]
# Question 4
#
# The following program is supposed to print
#
# The itsy bitsy spider climbed up the waterspout.
# Down came the rain
# and washed the spider out.
#
# but it contains two syntax errors and a logic error. Fix the errors so the program produces the correct output.
#
#
# print("The itsy bitsy spider")
# print("climbed up the waterspout.")
# print(Down came the rain)
#  print("and washed the spider out.")

# %%
print("The itsy bitsy spider climbed up the waterspout.")
print("Down came the rain")
print("and washed the spider out.")
# Out:
# The itsy bitsy spider climbed up the waterspout.
# Down came the rain
# and washed the spider out.

# %% [markdown]
# Question 5
#
# Fred’s Finest Furniture has a “we pay the sales tax” sale. But Fred doesn’t plan to actually pay the sales tax himself. So he has devised the following algorithm to adjust the prices of the items that he sells. Follow the algorithm and update the values in the columns as indicated. You'll probably need a calculator to follow along.

# %% [markdown]
# ![Screenshot 2024-01-11 at 1.12.55 PM.png](attachment:f5fa550f-f67b-4e35-9c3f-64466eb10854.png)
