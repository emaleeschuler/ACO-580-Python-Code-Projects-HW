# %% [markdown]
# ypat-axyz-axoz-vime Emalee Schuler

# %% [markdown]
# Question 1:
#
# In gymnastics and diving competitions, a competitor's total score, which is comprised of scores from eight judges, is computed by removing the highest and lowest score and then summing the remaining six scores. Use the functions from Section 6.2.7 to compute a competitor's total score from a list of scores awarded by the eight judges.

# %%
scores = [9.2, 8.6, 9.9, 9.4, 9.4, 9.8, 8.8, 9.1]

scores.remove(max(scores))
scores.remove(min(scores))

totalScore = sum(scores)

print("Score = %5.2f" % totalScore)
# Out:
# Score = 55.70

# %% [markdown]
# ![Screenshot%202024-02-15%20at%206.18.45%20PM.png](attachment:Screenshot%202024-02-15%20at%206.18.45%20PM.png)

# %% [markdown]
# Question 2:
#
# Complete the following function that builds and returns a string containing a sentence constructed from a list of words, with the individual words separated by a single blank space. For example, if the words list contains the strings ["The", "itsy", "bitsy", "spider"] the function call buildSentence(words) would return "The itsy bitsy spider".

# %% [markdown]
# ![Screenshot%202024-02-15%20at%206.38.22%20PM.png](attachment:Screenshot%202024-02-15%20at%206.38.22%20PM.png)

# %% [markdown]
# Question 3:
#
# Complete the following program that removes all negative numbers from a list of values.

# %%
values = [17, 25, -5, 30, 100, 96, -48, 5, 14, -30]

i = 0 
while i < len(values) :
    if values[i] < 0 : 
        del values[i]
    else:
        i = i + 1
    
print(values)
# Out:
# [17, 25, 30, 100, 96, 5, 14]

# %% [markdown]
# Question 4:
#
# Walk through the following code that swaps two elements in a list.!

# %% [markdown]
# ![Screenshot%202024-02-15%20at%206.50.59%20PM.png](attachment:Screenshot%202024-02-15%20at%206.50.59%20PM.png)

# %% [markdown]
# Question 5:
#
# Modify the algorithm in Section 6.3.3 and the code below so that it prints all positive values in a list, separated by commas.

# %%
values = [1, -2, 3, 4]  
printedValues = 0  # Variable to track the number of values printed

for i in range(len(values)) : 
    if values[i] >= 0:  # Check if the value is non-negative
        if printedValues > 0 :
            print(", ", end="")
        print(values[i], end="")
        printedValues = printedValues + 1
print()
# Out:
# 1, 3, 4
