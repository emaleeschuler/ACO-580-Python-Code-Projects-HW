# %% [markdown]
# osew-ikym-yreb-xixe Emalee Schuler

# %% [markdown]
# Question 1:
#
# Complete the following function that determines whether the set passed to the function is a subset of the set of rainbow colors.

# %%
def main() : 
    colors = {"red", "orange", "blue", "green"}
    if inRainbow(colors) : 
        print("rainbow colors")
    else :
        print("not rainbow colors")
 
##
# Determines whether the colors in the given set are a subset of the colors
# of a rainbow.
# @param colors a set of string representing color names
# @return a Boolean indicating whether the given colors are a subset of
# the reainbow colors
def inRainbow(colors) : 
    rainbow = {"red", "orange", "yellow", "green","blue", "indigo", "violet"}
    return colors.issubset(rainbow)
    
main()
# Out:
# rainbow colors

# %% [markdown]
# ![Screenshot%202024-02-22%20at%201.34.53%20PM.png](attachment:Screenshot%202024-02-22%20at%201.34.53%20PM.png)

# %% [markdown]
# Question 2:
#
# Given three baskets of fruit represented as Python sets, complete the following program using set operations to determine which fruits are in basket1 or basket2 but not in basket3.

# %%
basket1 = {"apples", "oranges", "grapes"}
basket2 = {"blueberries", "pears", "apples", "oranges", "lemons"}
basket3 = {"bananas", "lemons", "grapes", "apples"}

fruit = basket1.union(basket2) - basket3

for element in sorted(fruit) : 
    print(element, end=", ")
print()
# Out:
# blueberries, oranges, pears,

# %% [markdown]
# ![Screenshot%202024-02-22%20at%201.43.13%20PM.png](attachment:Screenshot%202024-02-22%20at%201.43.13%20PM.png)

# %% [markdown]
# Question 3:
#
# Your task is to write a program that reads a text string from the user and determines which letters of the alphabet are not used in the string.

# %%
inputStr = input("Enter a text string: ")
text = inputStr.upper()

# TODO: define a set named notUsed that contains the letters of
alphabet = set("ABCDEFGHIJKLMNOPQRSTUVWXYZ")

# the alphabet that are not contained in the user entered string.
notUsed = alphabet - set(text)

for element in sorted(notUsed) :
   print(element, end="")
print()
# Out:
# Enter a text string: A simple string.
# BCDFHJKOQUVWXYZ

# %% [markdown]
# ![Screenshot%202024-02-22%20at%201.45.07%20PM.png](attachment:Screenshot%202024-02-22%20at%201.45.07%20PM.png)

# %% [markdown]
# Quesiton 4:
#
# Trace through the following program that reads a collection of keys and values from the user and adds them to a dictionary:

# %%
data = {}
key = int(input("Enter key (0 to quit): "))
while key > 0 :  
   value = input("Enter value: ")
   data[key] = value
   size = len(data) 
   key = int(input("Enter key (0 to quit): "))
print(data[3])
# Out:
# Enter key (0 to quit): 3
# Enter value: A
# Enter key (0 to quit): 12
# Enter value: X
# Enter key (0 to quit): 9
# Enter value: X
# Enter key (0 to quit): 3
# Enter value: Y
# Enter key (0 to quit): 7
# Enter value: Q
# Enter key (0 to quit): 0
# Y

# %% [markdown]
# ![Screenshot%202024-02-22%20at%201.50.10%20PM.png](attachment:Screenshot%202024-02-22%20at%201.50.10%20PM.png)

# %% [markdown]
# Question 5:
#
# Complete the following program that acts as a translator for the periodic table of the elements. The program repeatedly prompts the user for an element symbol and then prints the element’s name or an error message until the user enters Q.
#
# Your program should use the prompt Enter symbol (or Q to quit): for user input. The output should be Invalid symbol if the user enters an invalid element symbol; otherwise the output is the translation in the format H = Hydrogen.

# %%
# The periodic table of elements.
periodicTable = {
   "H": "Hydrogen", "C": "Carbon", "O": "Oxygen",
   "Fe": "Iron", "Au": "Gold", "Na": "Sodium",
   "Ag": "Silver", "Pb": "Lead", "Pu": "Plutonimum"
}

# Use the prompt "Enter symbol (or Q to quit): "
# Print either "Invalid symbol." if an error occurs
# or "element = element name" ("%s = %s")

while True : 
    element = input("Enter symbol (or Q to quit): ")
    
    if element.upper() == 'Q' :
        break
    
    if element in periodicTable:
        element_name = periodicTable[element]
        print("%s = %s" % (element, element_name))
        
    else:
        print("Invalid symbol.")
# Out:
# Enter symbol (or Q to quit): O
# O = Oxygen
# Enter symbol (or Q to quit): Fe
# Fe = Iron
# Enter symbol (or Q to quit): :o
# Invalid symbol.
# Enter symbol (or Q to quit): Li
# Invalid symbol.
# Enter symbol (or Q to quit): Q

# %% [markdown]
# ![Screenshot%202024-02-22%20at%201.57.41%20PM.png](attachment:Screenshot%202024-02-22%20at%201.57.41%20PM.png)
